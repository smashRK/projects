# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/downloads/insurance.csv")

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
sex={'male':0,'female':1}
smoker={'yes':0,'no':1}
region={'northeast':0,'northwest':1,'southeast':2,'southwest':3}
df.sex=[sex[i] for i in df.sex]
df.smoker=[smoker[j] for j in df.smoker]
df.region=[region[k] for k in df.region]

# %%
df
# Out:
#       age  sex   bmi  children  smoker  region  expenses
# 0      19    1  27.9         0       0       3  16884.92
# 1      18    0  33.8         1       1       2   1725.55
# 2      28    0  33.0         3       1       2   4449.46
# 3      33    0  22.7         0       1       1  21984.47
# 4      32    0  28.9         0       1       1   3866.86
# ...   ...  ...   ...       ...     ...     ...       ...
# 1333   50    0  31.0         3       1       1  10600.55
# 1334   18    1  31.9         0       1       0   2205.98
# 1335   18    1  36.9         0       1       2   1629.83
# 1336   21    1  25.8         0       1       3   2007.95
# 1337   61    1  29.1         0       0       1  29141.36
#
# [1338 rows x 7 columns]

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=50)

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(ml.intercept_)
# Out:
# 12017.074940950477

# %%
print(ml.coef_)
# Out:
# [   251.39431125    318.92989923    302.84862867    405.25637414
#  -23155.11187846   -160.54816743]

# %%
y_pred=ml.predict(x_test)

# %%
y_pred
# Out:
# array([ 8112.46124225, 11594.56983532, 16889.41513598, 11220.62985876,
#          589.00225607, 38707.75541092, 26017.48582029,  8079.92677232,
#         1456.18646633, 11829.61208756,  9694.08845846, 31612.15126333,
#         7814.78220115, 30955.59602385,  7752.19117194,  9521.2380109 ,
#        11555.60859326,  4754.2741024 , 11946.17658632,  8481.53878158,
#        -1133.55403656, 36555.21552034,  6701.25141114,  9055.84316534,
#         4250.27249914, 10900.35235321,  5896.54967537, 37301.52547002,
#          533.65072479,   378.32125778, 36816.47053347,  4163.49302377,
#        14652.67377116,  1578.9463929 ,  1485.15472223,  5665.89480776,
#         9461.11772042,  1653.68359054, 11856.91147348, 38585.13628086,
#         9482.89585217,  6739.12567066, 16686.19557475, 13302.79409957,
#        35121.58969773, 13545.89793178, 33819.874757  ,  4457.09154758,
#        12798.87744656,  9411.56490867, 39189.72344715,  9349.71079925,
# ...

# %%
from sklearn import metrics
print('mean absolute error',metrics.mean_absolute_error(y_pred,y_test))
print('mean squared error',metrics.mean_squared_error(y_pred,y_test))
print('root mean sqared error',np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
# Out:
# mean absolute error 4052.9728730187617
# mean squared error 35195325.86350661
# root mean sqared error 5932.56486382632

# %%
y_pred=ml.predict(x_test)

# %%
y_pred
# Out:
# array([ 8112.46124225, 11594.56983532, 16889.41513598, 11220.62985876,
#          589.00225607, 38707.75541092, 26017.48582029,  8079.92677232,
#         1456.18646633, 11829.61208756,  9694.08845846, 31612.15126333,
#         7814.78220115, 30955.59602385,  7752.19117194,  9521.2380109 ,
#        11555.60859326,  4754.2741024 , 11946.17658632,  8481.53878158,
#        -1133.55403656, 36555.21552034,  6701.25141114,  9055.84316534,
#         4250.27249914, 10900.35235321,  5896.54967537, 37301.52547002,
#          533.65072479,   378.32125778, 36816.47053347,  4163.49302377,
#        14652.67377116,  1578.9463929 ,  1485.15472223,  5665.89480776,
#         9461.11772042,  1653.68359054, 11856.91147348, 38585.13628086,
#         9482.89585217,  6739.12567066, 16686.19557475, 13302.79409957,
#        35121.58969773, 13545.89793178, 33819.874757  ,  4457.09154758,
#        12798.87744656,  9411.56490867, 39189.72344715,  9349.71079925,
# ...

# %%
a=ml.predict([[52,0,38.6,2,1,3]])
score=a[0]
print(int(score))
# Out:
# 13953
